# %% [markdown]
# # this notebook is used for dev purposes

# %%
import torch
import torch.nn as nn
from torch.utils.data.dataloader import DataLoader
from torch.utils.data.dataset import Dataset
import os
import glob
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm


DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# base diffusion model will be IDDPM from https://github.com/openai/improved-diffusion/ adapted to the format of the submission
# let's get started. We going to begin implementaion from the dataset, we will use adopted food101 resized to 64x64 images

TRAIN_PATH = "/home/kolek/Edu/thesis/data/train"
TEST_PATH = "/home/kolek/Edu/thesis/data/test"

# the structure of the dataset is the following: each class of the image is places in the separate folder
# out network will be class conditioned so we need to extract this information as well

class Food101Dataset(Dataset):
    def __init__(self, directory_path, train=True):
        # get classes
        self.dataset_root = directory_path
        self.train = train
        class_names = os.listdir(directory_path)
        class_labels = range(0, len(class_names))
        # for convenience
        self.classes_to_num = {class_name:class_label for class_name, class_label in zip(class_names, class_labels)}
        self.num_to_classes = {class_label:class_name for class_name, class_label in zip(class_names, class_labels)}
        # get paths to the images
        self.image_paths = glob.glob(self.dataset_root + "/*/*")


        
    def __getitem__(self, idx):
        # load image and convert it to RGB
        image = Image.open(self.image_paths[idx])
        image = np.array(image.convert("RGB"))
        # normalize image to range [-1, 1]
        image = image.astype(np.float32) / 127.5 - 1
        # then convert to torch tensor
        image = torch.tensor(image, dtype=torch.float32)
                
        # deduct class label from path
        image_class = self.image_paths[idx].split("/")[-2]

        # to comply with improved diffusion unet channels should be
        # a first dimension and labels should be returns as a dict
        return image.permute([2, 0, 1]), {"y": self.classes_to_num[image_class]}

    def __len__(self):
        return len(self.image_paths)

# %%
dataset_train = Food101Dataset(TRAIN_PATH)
dataset_test = Food101Dataset(TEST_PATH)

# %%
# test
idx = 2
img, label = dataset_train[idx]
rgb = (img * 127.5 + 127.5).numpy().transpose([1, 2, 0])
print(dataset_train.image_paths[idx], rgb.min(), rgb.max())
plt.imshow(rgb.astype(np.uint8))
# Out:
# /home/kolek/Edu/thesis/data/train/beef_tartare/3599238.jpg 0.0 255.0

# %%
def plot_image_distributions(dataset):
    counter = {class_name:0 for class_name in dataset.classes_to_num.keys()}
    for path in dataset.image_paths:
    # exctract label value 
        class_name = path.split("/")[-2]
        counter[class_name] += 1
    # Example data
    classes = dataset.classes_to_num.keys()
    y_pos = np.arange(len(classes))
    number_of_images = counter.values()

    fig, ax = plt.subplots(figsize=(18, 18))
    hbars = ax.barh(y_pos, number_of_images, align='center')
    ax.set_yticks(y_pos, labels=classes)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Number of images')
    ax.set_title('How many images per each label')

    # Label with specially formatted floats
    ax.bar_label(hbars, fmt='%.2f')
    ax.set_xlim(right=1000)  # adjust xlim to fit labels

    plt.show()

# %%
plot_image_distributions(dataset_test)

# %% [markdown]
# > Roughly the same per each class

# %%
from models.improved_diffusion.unet import UNetModel

def create_model(
    image_size,
    num_channels,
    num_res_blocks,
    learn_sigma,
    class_cond,
    use_checkpoint,
    attention_resolutions,
    num_heads,
    num_heads_upsample,
    use_scale_shift_norm,
    dropout,
    num_classes
):
    if image_size == 256:
        channel_mult = (1, 1, 2, 2, 4, 4)
    elif image_size == 64:
        channel_mult = (1, 2, 3, 4)
    elif image_size == 32:
        channel_mult = (1, 2, 2, 2)
    else:
        raise ValueError(f"unsupported image size: {image_size}")

    attention_ds = []
    for res in attention_resolutions.split(","):
        attention_ds.append(image_size // int(res))

    return UNetModel(
        in_channels=3,
        model_channels=num_channels,
        out_channels=(3 if not learn_sigma else 6),
        num_res_blocks=num_res_blocks,
        attention_resolutions=tuple(attention_ds),
        dropout=dropout,
        channel_mult=channel_mult,
        num_classes=(num_classes if class_cond else None),
        use_checkpoint=use_checkpoint,
        num_heads=num_heads,
        num_heads_upsample=num_heads_upsample,
        use_scale_shift_norm=use_scale_shift_norm,
    )

# %%
from models.improved_diffusion import gaussian_diffusion as gd
from models.improved_diffusion.respace import SpacedDiffusion, space_timesteps

def create_gaussian_diffusion(
    *,
    steps=1000,
    learn_sigma=False,
    noise_schedule="linear",
    use_kl=False,
    predict_xstart=False,
    rescale_timesteps=False,
    rescale_learned_sigmas=False,
    timestep_respacing="",
    sigma_small
):
    betas = gd.get_named_beta_schedule(noise_schedule, steps)
    if use_kl:
        loss_type = gd.LossType.RESCALED_KL
    elif rescale_learned_sigmas:
        loss_type = gd.LossType.RESCALED_MSE
    else:
        loss_type = gd.LossType.MSE
    if not timestep_respacing:
        timestep_respacing = [steps]
    return SpacedDiffusion(
        use_timesteps=space_timesteps(steps, timestep_respacing),
        betas=betas,
        model_mean_type=(
            gd.ModelMeanType.EPSILON if not predict_xstart else gd.ModelMeanType.START_X
        ),
        model_var_type=(
            (
                gd.ModelVarType.FIXED_LARGE
                if not sigma_small
                else gd.ModelVarType.FIXED_SMALL
            )
            if not learn_sigma
            else gd.ModelVarType.LEARNED_RANGE
        ),
        loss_type=loss_type,
        rescale_timesteps=rescale_timesteps,
    )

# %%
def model_defaults():
    """
    Defaults for image training.
    """
    return dict(
        image_size=64,
        num_channels=128,
        num_res_blocks=2,
        num_heads=4,
        num_heads_upsample=-1,
        attention_resolutions="16,8",
        dropout=0.0,
        learn_sigma=False,
        class_cond=True,
        use_checkpoint=False,
        use_scale_shift_norm=True,
        num_classes = 101
    )


def diffusion_defaults():
    """
    Defaults for diffusion process
    """
    return dict(
        sigma_small=False,
        steps=1000,
        noise_schedule="cosine",
        timestep_respacing="",
        use_kl=False,
        predict_xstart=False,
        rescale_timesteps=True,
        rescale_learned_sigmas=True,
    )

# %%
# lets construct out first diffusion model
# we need to create:
# > model for reverse diffusion process
# > straight diffusion process
# > noise scheduler 

from models.improved_diffusion.scheduler import UniformSampler

# def calculate_number_of_trainable_params(model):
#     return sum(p.numel() for p in model.parameters() if p.requires_grad)

# model = create_model(
#     **model_defaults()
# ).to(DEVICE)

# diffusion = create_gaussian_diffusion(**diffusion_defaults())

# scheduler = UniformSampler(diffusion)
# print(f"number of trainable params: {calculate_number_of_trainable_params(model)}")

# %%
# # create a dataloader
# dataloader = DataLoader(dataset=dataset, shuffle=True, batch_size=2)
# batch = next(iter(dataloader))
# images, labels = batch

# %%
# optimizer = torch.optim.AdamW(model.parameters())

# %%
# Let's define a training step
# get batch
def train_step(model, diffusion, optimizer, batch, device):
    model.train()
    optimizer.zero_grad()
    images, labels = batch
    images = images.to(device)
    labels['y'] = labels['y'].to(device)
    # sample timesteps for the batch
    # returns timesteps per each sample in the batch and weights for each timestamp
    # in case of uniform scheduler weights for each timestamp is equal to 1
    t, weights = scheduler.sample(images.shape[0], device)

    # internally this function:
    # > generate random noise to apply to the image
    # > does straight diffusion process with this noise
    # > gets the output from the model
    # > calculated loss
    losses = diffusion.training_losses(model=model, x_start=images, t=t, model_kwargs=labels)

    # loss: could be KL or MSE, or rescaled ones. Default rescaled MSE
    loss = losses["loss"].mean()


    loss.backward()
    # TODO add annealing
    optimizer.step()

# %%
#train_step(model, diffusion, optimizer, batch, DEVICE)

# %%
# Let's define how to sample from model
# in order to sample we need diffusion class, model and labels

def sample(model, diffusion, shape, labels, device):
    model.eval()
    with torch.no_grad():
        samples = diffusion.p_sample_loop(model, shape, model_kwargs=labels, device=device)
    return samples

# %%
# samples = sample(model, diffusion, images.shape, labels, DEVICE)
# # reconstruct images from samples

# img = samples[0].permute([1, 2, 0]).detach().cpu().numpy()
# img = ((img + 1) * 127.5).astype(np.uint8)
# img = img.clip(0, 255)
# plt.title("Reconstructed img")
# plt.imshow(img)

# %%
# lets implement simple Trainer class

class Trainer():
    def __init__(self,
                 model,
                 diffusion,
                 scheduler,
                 dataloader,
                 optimizer,
                 num_epochs,
                 load_checkpoint_path,
                 save_checkpoint_path,
                 log_every,
                 save_every,
                 device):
        self.model = model
        self.diffusion = diffusion
        self.scheduler = scheduler
        self.dataloader = dataloader
        self.optimizer = optimizer
        self.num_epochs = num_epochs
        self.device = device
        self.load_checkpoint_path = load_checkpoint_path
        self.save_checkpoint_path = save_checkpoint_path
        self.log_every = log_every
        self.save_every = save_every

        self.model = self.model.to(self.device)
        self.train_losses = []
        self.iteration_count = 0
        self.load_checkpoint()
    
    def train_step(self, images, labels):
        self.model.train()
        self.optimizer.zero_grad()
        images = images.to(self.device)
        labels['y'] = labels['y'].to(self.device)
        # sample timesteps for the batch
        # returns timesteps per each sample in the batch and weights for each timestamp
        # in case of uniform scheduler, weights for each timestamp is equal to 1
        t, _ = self.scheduler.sample(images.shape[0], self.device)

        # internally this function:
        # > generates random noise to apply to the image
        # > does forward diffusion process
        # > gets the output from the model
        # > calculates loss
        losses = self.diffusion.training_losses(model=self.model, x_start=images, t=t, model_kwargs=labels)

        # loss: could be KL or MSE, or rescaled ones. Default rescaled MSE
        loss = losses["loss"].mean()
        loss.backward()
        # TODO add annealing
        self.optimizer.step()
        return loss.item()
    
    def save_checkpoint(self):
        print(f"Saving checkpoint at: {self.save_checkpoint_path}")
        torch.save({
            "model_state_dict": self.model.state_dict(),
            "optimizer_state_dict": self.optimizer.state_dict(),
            "diffusion": self.diffusion,
            "train_losses": self.train_losses,
            "scheduler": self.scheduler,
            "iteration_count": self.iteration_count
        }, self.save_checkpoint_path)
    
    def update_learning_rate(self, lr):
        for param_group in self.optimizer.param_groups:
            param_group["lr"] = lr

    def load_checkpoint(self):
        print(f"Loading checkpoint: {self.load_checkpoint_path}")
        if not os.path.isfile(self.load_checkpoint_path):
            print("Err: no such file, not loading")
            return
        dict = torch.load(self.load_checkpoint_path)
        self.model.load_state_dict(dict["model_state_dict"])
        self.optimizer.load_state_dict(dict["optimizer_state_dict"])
        self.diffusion = dict["diffusion"]
        self.train_losses = dict["train_losses"]
        self.scheduler = dict["scheduler"]
        self.iteration_count = dict['iteration_count']
        print(f"Last train loss: {self.train_losses[-1]}\n"
              f"Model trained for {self.iteration_count} iterations")


    def train_loop(self):
        for epoch in range(self.num_epochs):
            for iteration, (images, labels) in enumerate(tqdm(self.dataloader, desc=f"Epoch: {epoch}/{self.num_epochs}")):
                train_loss = self.train_step(images, labels)
                if iteration % self.log_every == 0:
                    self.train_losses.append(train_loss)
                    print(f">> train loss: {train_loss}")
                if iteration % self.save_every == 0:
                    self.save_checkpoint()
                # TODO: add validation and logging
                self.iteration_count += 1

    def validation_step(self):
        pass

# %%
dataloader = DataLoader(dataset=dataset, shuffle=True, batch_size=10, num_workers=4, pin_memory=True)

model = create_model(**model_defaults()).to(DEVICE)

diffusion = create_gaussian_diffusion(**diffusion_defaults())

scheduler = UniformSampler(diffusion)

optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

trainer = Trainer(model=model,
                  diffusion=diffusion,
                  scheduler=scheduler,
                  dataloader=dataloader,
                  optimizer=optimizer,
                  num_epochs=100,
                  device=DEVICE,
                  save_checkpoint_path="./diffusion_rescaled_mse_cosine.pkl",
                  load_checkpoint_path="./diffusion_rescaled_mse_cosine.pkl",
                  log_every=50,
                  save_every=200)
# Out:
# Loading checkpoint: ./diffusion_rescaled_mse_cosine.pkl
# /tmp/ipykernel_693981/3379846211.py:77: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   dict = torch.load(self.load_checkpoint_path)
# Last train loss: 0.03145332634449005
# Model trained for 16400 iterations

# %%
trainer.update_learning_rate(1e-4)

# %%
trainer.train_loop()
# Out:
# Epoch: 0/100:   0%|          | 0/9894 [00:00<?, ?it/s]
# >> train loss: 0.08810832351446152
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.03307485207915306
# >> train loss: 0.03822995349764824
# >> train loss: 0.05082544684410095
# >> train loss: 0.05016293749213219
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.05228252336382866
# >> train loss: 0.11815809458494186
# >> train loss: 0.08851370960474014
# >> train loss: 0.0881604328751564
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.05255010351538658
# >> train loss: 0.01913297548890114
# >> train loss: 0.0885171890258789
# >> train loss: 0.08968623727560043
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.08233524858951569
# >> train loss: 0.039237089455127716
# >> train loss: 0.03724057227373123
# >> train loss: 0.028115659952163696
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.043652329593896866
# >> train loss: 0.05748472735285759
# >> train loss: 0.050005991011857986
# >> train loss: 0.1006230041384697
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.12296845763921738
# >> train loss: 0.03951871022582054
# >> train loss: 0.036482203751802444
# >> train loss: 0.036416079849004745
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.07389436662197113
# >> train loss: 0.025046471506357193
# >> train loss: 0.06361376494169235
# >> train loss: 0.034847114235162735
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06924992054700851
# >> train loss: 0.08892514556646347
# >> train loss: 0.04369973763823509
# >> train loss: 0.03988020494580269
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.018081100657582283
# >> train loss: 0.059261299669742584
# >> train loss: 0.051852501928806305
# >> train loss: 0.030750244855880737
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.035033565014600754
# >> train loss: 0.10687162727117538
# >> train loss: 0.07225333154201508
# >> train loss: 0.026411205530166626
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.04014188423752785
# >> train loss: 0.020365668460726738
# >> train loss: 0.05024859309196472
# >> train loss: 0.07627455145120621
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06406736373901367
# >> train loss: 0.0796746164560318
# >> train loss: 0.06578149646520615
# >> train loss: 0.042159318923950195
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.03269767761230469
# >> train loss: 0.03299278765916824
# >> train loss: 0.050470441579818726
# >> train loss: 0.028795910999178886
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.05354219302535057
# >> train loss: 0.036650385707616806
# >> train loss: 0.06083929166197777
# >> train loss: 0.09526319056749344
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.07227303087711334
# >> train loss: 0.09462733566761017
# >> train loss: 0.045485250651836395
# >> train loss: 0.0394609272480011
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06380718946456909
# >> train loss: 0.05801744386553764
# >> train loss: 0.03462094068527222
# >> train loss: 0.03937399014830589
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.053450632840394974
# >> train loss: 0.058201491832733154
# >> train loss: 0.04413414001464844
# >> train loss: 0.04478234425187111
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.01347727794200182
# >> train loss: 0.017395202070474625
# >> train loss: 0.05795681104063988
# >> train loss: 0.06376700103282928
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.07098657637834549
# >> train loss: 0.0520520880818367
# >> train loss: 0.03344851732254028
# >> train loss: 0.06699049472808838
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.033461108803749084
# >> train loss: 0.015527049079537392
# >> train loss: 0.03892756626009941
# >> train loss: 0.08229299634695053
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.035868193954229355
# >> train loss: 0.02849849872291088
# >> train loss: 0.07763475924730301
# >> train loss: 0.04560784623026848
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.041278015822172165
# >> train loss: 0.024764465168118477
# >> train loss: 0.04955459386110306
# >> train loss: 0.038950126618146896
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.03736093267798424
# >> train loss: 0.07549168914556503
# >> train loss: 0.06633272022008896
# >> train loss: 0.03449647128582001
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.028422608971595764
# >> train loss: 0.03658093884587288
# >> train loss: 0.04375898465514183
# >> train loss: 0.045669108629226685
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06967806071043015
# >> train loss: 0.05698955059051514
# >> train loss: 0.03312312811613083
# >> train loss: 0.06420744955539703
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.0747271329164505
# >> train loss: 0.05699307844042778
# >> train loss: 0.032426729798316956
# >> train loss: 0.07670824974775314
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.05671508237719536
# >> train loss: 0.028475521132349968
# >> train loss: 0.057312723249197006
# >> train loss: 0.04284617304801941
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.04043404385447502
# >> train loss: 0.05976594239473343
# >> train loss: 0.03700122982263565
# >> train loss: 0.0366552360355854
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06172044202685356
# >> train loss: 0.0748768001794815
# >> train loss: 0.03930095583200455
# >> train loss: 0.07195907831192017
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.016570307314395905
# >> train loss: 0.0993272215127945
# >> train loss: 0.05556541681289673
# >> train loss: 0.07062895596027374
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.030199546366930008
# >> train loss: 0.08223573118448257
# >> train loss: 0.07119530439376831
# >> train loss: 0.04275823384523392
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.04659061133861542
# >> train loss: 0.09165540337562561
# >> train loss: 0.06319615989923477
# >> train loss: 0.04770902171730995
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.08432425558567047
# >> train loss: 0.020265502855181694
# >> train loss: 0.06747721880674362
# >> train loss: 0.03632659465074539
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.03533370420336723
# >> train loss: 0.05817500501871109
# >> train loss: 0.06256838142871857
# >> train loss: 0.04515187069773674
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.08413999527692795
# >> train loss: 0.03927162289619446
# >> train loss: 0.03838808089494705
# >> train loss: 0.06271080672740936
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.05769498273730278
# >> train loss: 0.048205312341451645
# >> train loss: 0.02069091983139515
# >> train loss: 0.050015050917863846
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.07874010503292084
# >> train loss: 0.05654881149530411
# >> train loss: 0.053260769695043564
# >> train loss: 0.09787115454673767
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.0942160040140152
# >> train loss: 0.06400462239980698
# >> train loss: 0.04243027791380882
# >> train loss: 0.04580479487776756
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06656590849161148
# >> train loss: 0.06246304139494896
# >> train loss: 0.052115339785814285
# >> train loss: 0.02058093622326851
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.03731229528784752
# >> train loss: 0.04678044840693474
# >> train loss: 0.063086599111557
# >> train loss: 0.025219151750206947
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.04251547530293465
# >> train loss: 0.03117433190345764
# >> train loss: 0.06876929849386215
# >> train loss: 0.03798268362879753
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.04270133376121521
# >> train loss: 0.04710685461759567
# >> train loss: 0.04834313318133354
# >> train loss: 0.02916903607547283
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.028690675273537636
# >> train loss: 0.05721788480877876
# >> train loss: 0.08022738993167877
# >> train loss: 0.046089716255664825
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06307116895914078
# >> train loss: 0.03935303911566734
# >> train loss: 0.04675837978720665
# >> train loss: 0.047172266989946365
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.07491550594568253
# >> train loss: 0.04520362988114357
# >> train loss: 0.04310779646039009
# >> train loss: 0.034168679267168045
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.046347297728061676
# >> train loss: 0.04518913850188255
# >> train loss: 0.012555641122162342
# >> train loss: 0.01678355783224106
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.03819859027862549
# >> train loss: 0.02976883389055729
# >> train loss: 0.049476951360702515
# >> train loss: 0.048036400228738785
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.058493804186582565
# >> train loss: 0.051014650613069534
# >> train loss: 0.055632155388593674
# >> train loss: 0.028735477477312088
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.04657509922981262
# >> train loss: 0.039609283208847046
# >> train loss: 0.022890178486704826
# >> train loss: 0.0319424644112587
# Saving checkpoint at: ./diffusion_rescaled_mse_cosine.pkl
# >> train loss: 0.06967955827713013
# Epoch: 1/100:   0%|          | 0/9894 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 trainer.train_loop()
#
# Cell In[17], line 91, in Trainer.train_loop(self)
#      89 for epoch in range(self.num_epochs):
#      90     for iteration, (images, labels) in enumerate(tqdm(self.dataloader, desc=f"Epoch: {epoch}/{self.num_epochs}")):
# ---> 91         train_loss = self.train_step(images, labels)
#      92         if iteration % self.log_every == 0:
#      93             self.train_losses.append(train_loss)
#
# Cell In[17], line 48, in Trainer.train_step(self, images, labels)
#      41 t, _ = self.scheduler.sample(images.shape[0], self.device)
#      43 # internally this function:
#      44 # > generates random noise to apply to the image
#      45 # > does forward diffusion process
#      46 # > gets the output from the model
#      47 # > calculates loss
# ---> 48 losses = self.diffusion.training_losses(model=self.model, x_start=images, t=t, model_kwargs=labels)
#      50 # loss: could be KL or MSE, or rescaled ones. Default rescaled MSE
#      51 loss = losses["loss"].mean()
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/respace.py:96, in SpacedDiffusion.training_losses(self, model, *args, **kwargs)
#      93 def training_losses(
#      94     self, model, *args, **kwargs
#      95 ):  # pylint: disable=signature-differs
# ---> 96     return super().training_losses(self._wrap_model(model), *args, **kwargs)
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/gaussian_diffusion.py:710, in GaussianDiffusion.training_losses(self, model, x_start, t, model_kwargs, noise)
#     708         terms["loss"] *= self.num_timesteps
#     709 elif self.loss_type == LossType.MSE or self.loss_type == LossType.RESCALED_MSE:
# --> 710     model_output = model(x_t, self._scale_timesteps(t), **model_kwargs)
#     712     if self.model_var_type in [
#     713         ModelVarType.LEARNED,
#     714         ModelVarType.LEARNED_RANGE,
#     715     ]:
#     716         B, C = x_t.shape[:2]
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/respace.py:122, in _WrappedModel.__call__(self, x, ts, **kwargs)
#     120 if self.rescale_timesteps:
#     121     new_ts = new_ts.float() * (1000.0 / self.original_num_steps)
# --> 122 return self.model(x, new_ts, **kwargs)
#
# File ~/miniconda3/envs/usual/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/usual/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/unet.py:489, in UNetModel.forward(self, x, timesteps, y)
#     487 for module in self.output_blocks:
#     488     cat_in = th.cat([h, hs.pop()], dim=1)
# --> 489     h = module(cat_in, emb)
#     490 h = h.type(x.dtype)
#     491 return self.out(h)
#
# File ~/miniconda3/envs/usual/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/usual/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/unet.py:44, in TimestepEmbedSequential.forward(self, x, emb)
#      42 for layer in self:
#      43     if isinstance(layer, TimestepBlock):
# ---> 44         x = layer(x, emb)
#      45     else:
#      46         x = layer(x)
#
# File ~/miniconda3/envs/usual/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/usual/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/unet.py:180, in ResBlock.forward(self, x, emb)
#     172 def forward(self, x, emb):
#     173     """
#     174     Apply the block to a Tensor, conditioned on a timestep embedding.
#     175
#    (...)
#     178     :return: an [N x C x ...] Tensor of outputs.
#     179     """
# --> 180     return checkpoint(
#     181         self._forward, (x, emb), self.parameters(), self.use_checkpoint
#     182     )
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/nn.py:139, in checkpoint(func, inputs, params, flag)
#     137     return CheckpointFunction.apply(func, len(inputs), *args)
#     138 else:
# --> 139     return func(*inputs)
#
# File ~/Edu/thesis/genai_task/models/improved_diffusion/unet.py:197, in ResBlock._forward(self, x, emb)
#     195     h = h + emb_out
#     196     h = self.out_layers(h)
# --> 197 return self.skip_connection(x) + h
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 3.81 GiB of which 18.06 MiB is free. Including non-PyTorch memory, this process has 3.79 GiB memory in use. Of the allocated memory 3.52 GiB is allocated by PyTorch, and 198.44 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
idx = 2
samples = sample(model, diffusion, (1, 3, 64, 64), {"y": torch.tensor([idx], dtype=torch.long, device=DEVICE)}, DEVICE)
img = samples[0].permute([1, 2, 0]).detach().cpu().numpy()
img = ((img + 1) * 127.5).astype(np.uint8)
img = img.clip(0, 255)
plt.title(f"Reconstructed img of {dataset.num_to_classes[idx]}")
plt.imshow(img)
plt.imsave("image.jpg", img)
